# %%
# Write a Python program to generate a binomial distribution with n=10 and
p=0.5, then plot its histogram.

Hint: Generate random number using random function.

Program =>

import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10   # number of trials
p = 0.5  # probability of success
size = 1000  # number of random samples

# Generate random binomial data
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(n+2), edgecolor='black', align='left')
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %%
# Implement hypothesis testing using Z-statistics for a sample dataset in
Python. Show the Python code and interpret the results.
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

Program =>
import numpy as np
from scipy.stats import norm

# Sample data
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# Parameters
mu_0 = 50       # Hypothesized population mean
sigma = 1       # Assumed population standard deviation
alpha = 0.05    # Significance level

# Sample statistics
n = len(sample_data)
sample_mean = np.mean(sample_data)

# Z-statistic
z = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z)))

# Results
print("Sample Mean:", sample_mean)
print("Z-statistic:", z)
print("p-value:", p_value)

# Decision
if p_value < alpha:
    print("Reject H0: Evidence suggests the mean is significantly different
    from 50.")
else:
    print("Fail to Reject H0: No significant evidence that the mean differs
    from 50.")
# Out:
# Sample Mean: 50.08888888888889
# Z-statistic: 0.5333333333333314
# p-value: 0.5938028572077036
# Fail to Reject H0: No significant evidence that the mean differs from 50.

# %%
# Write a Python script to simulate data from a normal distribution and
calculate the 95% confidence interval for its mean. Plot the data using
Matplotlib.

Program =>

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate normal data
np.random.seed(42)  # for reproducibility
mu, sigma = 50, 5   # true mean and std deviation
n = 100             # sample size
data = np.random.normal(mu, sigma, n)

# Step 2: Calculate 95% confidence interval
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # sample standard deviation
confidence_level = 0.95
alpha = 1 - confidence_level

# Margin of error using t-distribution
t_crit = stats.t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_crit * (sample_std / np.sqrt(n))

ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"Sample Mean = {sample_mean:.2f}")
print(f"95% Confidence Interval = ({ci_lower:.2f}, {ci_upper:.2f})")

# Step 3: Plot histogram of data
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(sample_mean, color='red', linestyle='dashed', linewidth=2,
            label=f"Mean = {sample_mean:.2f}")
plt.axvline(ci_lower, color='green', linestyle='dashed', linewidth=2,
            label=f"Lower CI = {ci_lower:.2f}")
plt.axvline(ci_upper, color='green', linestyle='dashed', linewidth=2,
            label=f"Upper CI = {ci_upper:.2f}")

plt.title("Normal Distribution with 95% Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Sample Mean = 49.48
# 95% Confidence Interval = (48.58, 50.38)

# %%
# Write a Python function to calculate the Z-scores from a dataset and
visualize the standardized data using a histogram. Explain what the Z-scores
represent in terms of standard deviations from the mean.

Program =>

import numpy as np
import matplotlib.pyplot as plt

def calculate_zscores(data):
    """
    Function to calculate Z-scores and plot histogram.
    """
    mean = np.mean(data)
    std = np.std(data, ddof=1)  # sample std deviation
    z_scores = (data - mean) / std

    # Print mean and std for reference
    print(f"Mean of data = {mean:.2f}, Standard Deviation = {std:.2f}")

    # Plot histogram of Z-scores
    plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
    plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean
     (Z=0)")
    plt.title("Histogram of Z-scores (Standardized Data)")
    plt.xlabel("Z-score (Standard Deviations from Mean)")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

    return z_scores

# Example usage
np.random.seed(42)
data = np.random.normal(50, 5, 100)  # Normal distribution, mean=50, std=5
z_scores = calculate_zscores(data)
# Out:
# Mean of data = 49.48, Standard Deviation = 4.54

# %% [markdown]
# Statistics Advanced - 2 | Assignment

# %% [markdown]
# Question 1: What is hypothesis testing in statistics?
#
# Answer :- Hypothesis testing in statistics is a method used to make decisions or inferences about a population based on sample data.
#
# Key Points:
#
# 1. Hypothesis
#
# * Null Hypothesis (H₀): The default assumption, e.g., “There is no effect” or “The means are equal.”
# * Alternative Hypothesis (H₁ or Ha): What you want to test, e.g., “There is an effect” or “The means are not equal.”
#
# 2. Steps in Hypothesis Testing
#
# * State the null (H₀) and alternative (H₁) hypotheses.
# * Choose a significance level (α, usually 0.05).
# * Collect and analyze sample data.
# * Calculate the test statistic (e.g., z, t, chi-square, F).
# * Find the p-value or compare the test statistic with a critical value.
# * Decision rule:
# 1. If p-value ≤ α, reject H₀ (evidence supports H₁).
# 2. If p-value > α, fail to reject H₀ (not enough evidence).
#
# 3. Example
# Suppose a company claims that the average life of its batteries is 500 hours.
# * H₀: μ = 500 (average life = 500 hours)
# * H₁: μ ≠ 500 (average life is not 500 hours)
# By testing a sample of batteries, we can check if the claim is statistically valid.
#
# Question 2: What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# Answer :- 1. Null Hypothesis (H₀)
# * It is the default assumption in hypothesis testing.
# * It states that there is no effect, no difference, or no relationship in the population.
# * Example: “The average height of students in a class is 160 cm.” (H₀: μ = 160)
#
# 2. Alternative Hypothesis (H₁ or Ha)
# * It is the opposite of the null hypothesis.
# * It states that there is an effect, difference, or relationship.
# * Example: “The average height of students is not 160 cm.” (H₁: μ ≠ 160)
#
# Question 3: Explain the significance level in hypothesis testing and its role in deciding the outcome of a test.
#
# Answer :- Significance Level (α) in Hypothesis Testing
# * The significance level (α) is the threshold probability we set to decide whether to reject the null hypothesis (H₀).
# * It represents the risk of making a Type I error → rejecting H₀ when it is actually true.
#
# Common values: 0.05 (5%), 0.01 (1%), or 0.10 (10%).
#
# Role in Hypothesis Testing
#
# 1. Set α before testing (e.g., α = 0.05).
# 2. After calculating the test statistic, we find the p-value.
# * If p-value ≤ α → Reject H₀ (evidence is strong enough).
# * If p-value > α → Fail to reject H₀ (not enough evidence).
#
# Example
#
# Suppose a drug company claims its medicine lowers blood pressure.
# * H₀: The medicine has no effect.
# * H₁: The medicine reduces blood pressure.
# * Significance level α = 0.05.
#
# After testing, p-value = 0.03.
# * Since 0.03 ≤ 0.05 → Reject H₀.
# * Conclusion: The medicine is effective (with 95% confidence).
#
# Question 4: What are Type I and Type II errors? Give examples of each.
#
# Answer :- 1. Type I Error (False Positive)
# * Happens when we reject the null hypothesis (H₀) even though it is true.
# * In other words, we think there is an effect, but actually, there isn’t.
# * Probability of making this error = α (significance level).
#
# Example:
# * A medical test shows a patient has a disease when in reality, they are healthy.
# * Court trial analogy: An innocent person is convicted.
#
# 2. Type II Error (False Negative)
# * Happens when we fail to reject the null hypothesis (H₀) even though it is false.
# * In other words, we miss a real effect.
# * Probability of making this error = β (related to the power of the test = 1 - β).
#
# Example:
# * A medical test says a patient is healthy when in reality, they have the disease.
# * Court trial analogy: A guilty person is set free.
#
# Question 5: What is the difference between a Z-test and a T-test? Explain when to use each.
#
# Answer :- 1. Z-Test
# * A Z-test is used when:
# 1. The population variance (σ²) or standard deviation (σ) is known.
# 2. The sample size is large (n > 30, Central Limit Theorem applies).
# * It uses the standard normal distribution (Z-distribution).
#
# Example:
# A factory claims the average weight of a packet is 500 g. You have a sample of 100 packets, and the population standard deviation (σ) is known. → Use Z-test.
#
# 2. T-Test
# * A T-test is used when:
# 1. The population variance (σ²) is unknown.
# 2. The sample size is small (n ≤ 30).
# * It uses the Student’s t-distribution, which has heavier tails (accounts for extra uncertainty).
#
# Example:
# A teacher wants to check if the average marks of 15 students differ from 70, but the population standard deviation is unknown. → Use T-test.
